# %%
import pandas as pd

# %%
# !pip install geopandas

# %%
import geopandas as gpd
from shapely.geometry import Point

# %%
#Estado de São Paulo
sp_uf = gpd.read_file('/content/drive/My Drive/Mini Projetos Data Science/Mapas de São Paulo/SP_UF_2019.shp')
sp_uf
# Out:
#   CD_UF      NM_UF  ... NM_REGIAO                                           geometry
# 0    35  São Paulo  ...   Sudeste  MULTIPOLYGON (((-48.03716 -25.35794, -48.03750...
#
# [1 rows x 5 columns]

# %%
#Mapa do Estado de São Paulo
sp_uf = sp_uf.plot(figsize=(20,20))
sp_uf.axis('off') #Retira os eixos
# Out:
# (-53.5575488504, -43.71392784560001, -25.63691697715, -19.50073859585)

# %%
#Municípios de SP
municipios = gpd.read_file('/content/drive/My Drive/Mini Projetos Data Science/Mapas de São Paulo/SP_Municipios_2019.shp')
municipios
# Out:
#       CD_MUN  ...                                           geometry
# 0    3500105  ...  POLYGON ((-51.17919 -21.68790, -51.17924 -21.6...
# 1    3500204  ...  POLYGON ((-49.61249 -21.26110, -49.61249 -21.2...
# 2    3500303  ...  POLYGON ((-47.21948 -22.03920, -47.21784 -22.0...
# 3    3500402  ...  POLYGON ((-46.73076 -21.94354, -46.73084 -21.9...
# 4    3500501  ...  POLYGON ((-46.66057 -22.47957, -46.66064 -22.4...
# ..       ...  ...                                                ...
# 640  3557006  ...  POLYGON ((-47.50719 -23.54673, -47.50809 -23.5...
# 641  3557105  ...  POLYGON ((-50.03205 -20.42645, -50.03200 -20.4...
# 642  3557154  ...  POLYGON ((-49.98507 -21.05306, -49.98518 -21.0...
# 643  3557204  ...  POLYGON ((-49.74234 -23.02696, -49.74402 -23.0...
# 644  3557303  ...  POLYGON ((-46.96444 -22.29548, -46.96610 -22.2...
#
# [645 rows x 5 columns]

# %%
#Mapa dos municípios de SP
municipios = municipios.plot(figsize=(20,20), color = 'grey', edgecolor = 'white', linewidth = 1)
municipios.axis('off')
# Out:
# (-53.5575488504, -43.71392784560001, -25.63691697715, -19.50073859585)

# %%
#Mesorregiões de SP
meso = gpd.read_file('/content/drive/My Drive/Mini Projetos Data Science/Mapas de São Paulo/SP_Mesorregioes_2019.shp')
meso
# Out:
#    CD_MESO  ...                                           geometry
# 0     3501  ...  POLYGON ((-50.81212 -20.53115, -50.81288 -20.5...
# 1     3502  ...  POLYGON ((-47.86981 -20.07615, -47.86960 -20.0...
# 2     3503  ...  POLYGON ((-51.57519 -20.62342, -51.57518 -20.6...
# 3     3504  ...  POLYGON ((-49.42280 -22.29420, -49.42278 -22.2...
# 4     3505  ...  POLYGON ((-48.47108 -21.51269, -48.47221 -21.5...
# 5     3506  ...  POLYGON ((-48.23485 -22.52038, -48.23523 -22.5...
# 6     3507  ...  POLYGON ((-47.19749 -22.09872, -47.23234 -22.0...
# 7     3508  ...  POLYGON ((-51.96222 -21.49331, -51.96210 -21.4...
# 8     3509  ...  POLYGON ((-50.73710 -21.87756, -50.73415 -21.8...
# 9     3510  ...  POLYGON ((-50.78354 -22.43519, -50.78391 -22.4...
# 10    3511  ...  POLYGON ((-48.22490 -23.19625, -48.22420 -23.1...
# 11    3512  ...  POLYGON ((-46.44284 -22.82453, -46.43968 -22.8...
# 12    3513  ...  MULTIPOLYGON (((-45.66298 -24.08365, -45.66318...
# ...

# %%
#Mapa das mesorregiões de SP
meso = meso.plot(figsize=(20,20), color = 'grey', edgecolor = 'white', linewidth = 1)
meso.axis('off')
# Out:
# (-53.5575488504, -43.71392784560001, -25.63691697715, -19.50073859585)

# %%
#Microrregiões de SP
micro = gpd.read_file('/content/drive/My Drive/Mini Projetos Data Science/Mapas de São Paulo/SP_Microrregioes_2019.shp')
micro
# Out:
#    CD_MICRO  ...                                           geometry
# 0     35001  ...  POLYGON ((-51.00119 -20.09633, -51.00109 -20.0...
# 1     35002  ...  POLYGON ((-50.43332 -19.98373, -50.43348 -19.9...
# 2     35003  ...  POLYGON ((-49.90619 -19.93717, -49.90522 -19.9...
# 3     35004  ...  POLYGON ((-49.57621 -20.78920, -49.57748 -20.7...
# 4     35005  ...  POLYGON ((-49.11108 -21.02710, -49.11158 -21.0...
# ..      ...  ...                                                ...
# 58    35059  ...  POLYGON ((-46.36416 -23.27408, -46.36392 -23.2...
# 59    35060  ...  POLYGON ((-46.98892 -23.80081, -46.98928 -23.8...
# 60    35061  ...  POLYGON ((-46.33072 -23.70887, -46.33066 -23.7...
# 61    35062  ...  POLYGON ((-45.96191 -23.49705, -45.96180 -23.4...
# 62    35063  ...  MULTIPOLYGON (((-46.16241 -24.33113, -46.16298...
#
# [63 rows x 4 columns]

# %%
#Mapa das microrregiões de SP
micro = micro.plot(figsize=(20,20), color = 'grey', edgecolor = 'white', linewidth = 1)
micro.axis('off')
# Out:
# (-53.5575488504, -43.71392784560001, -25.63691697715, -19.50073859585)

# %%
#Regiões imediatas de SP
imediatas = gpd.read_file('/content/drive/My Drive/Mini Projetos Data Science/Mapas de São Paulo/SP_RG_Imediatas_2019.shp')
imediatas
# Out:
#     CD_RGI  ...                                           geometry
# 0   350001  ...  POLYGON ((-46.36416 -23.27408, -46.36392 -23.2...
# 1   350002  ...  MULTIPOLYGON (((-46.67622 -24.47816, -46.67613...
# 2   350003  ...  POLYGON ((-47.38956 -23.15466, -47.38905 -23.1...
# 3   350004  ...  POLYGON ((-48.78096 -23.64280, -48.78004 -23.6...
# 4   350005  ...  MULTIPOLYGON (((-48.03716 -25.35794, -48.03750...
# 5   350006  ...  POLYGON ((-48.53492 -23.54114, -48.53672 -23.5...
# 6   350007  ...  POLYGON ((-49.24545 -23.14475, -49.24594 -23.1...
# 7   350008  ...  POLYGON ((-48.15520 -23.26184, -48.15702 -23.2...
# 8   350009  ...  POLYGON ((-49.21329 -21.67114, -49.21214 -21.6...
# 9   350010  ...  POLYGON ((-48.77154 -22.22699, -48.77950 -22.2...
# 10  350011  ...  POLYGON ((-48.68867 -22.69434, -48.68914 -22.6...
# 11  350012  ...  POLYGON ((-49.77209 -21.80437, -49.77191 -21.8...
# 12  350013  ...  POLYGON ((-50.12805 -21.81702, -50.12811 -21.8...
# ...

# %%
#Mapa das regiões imediatas de SP
imediatas = imediatas.plot(figsize=(20,20), color = 'grey', edgecolor = 'white', linewidth = 1)
imediatas.axis('off')
# Out:
# (-53.5575488504, -43.71392784560001, -25.63691697715, -19.50073859585)

# %%
#Regiões intermediárias de SP
intermediarias = gpd.read_file('/content/drive/My Drive/Mini Projetos Data Science/Mapas de São Paulo/SP_RG_Intermediarias_2019.shp')
intermediarias
# Out:
#    CD_RGINT  ...                                           geometry
# 0      3501  ...  MULTIPOLYGON (((-46.67622 -24.47816, -46.67613...
# 1      3502  ...  MULTIPOLYGON (((-48.03716 -25.35794, -48.03750...
# 2      3503  ...  POLYGON ((-49.55642 -22.12980, -49.55641 -22.1...
# 3      3504  ...  POLYGON ((-50.55847 -22.29529, -50.55854 -22.2...
# 4      3505  ...  POLYGON ((-51.96222 -21.49331, -51.96210 -21.4...
# 5      3506  ...  POLYGON ((-51.57519 -20.62342, -51.57518 -20.6...
# 6      3507  ...  POLYGON ((-51.03857 -20.37092, -51.03871 -20.3...
# 7      3508  ...  POLYGON ((-48.94909 -20.86933, -48.94938 -20.8...
# 8      3509  ...  POLYGON ((-49.08403 -21.75559, -49.08559 -21.7...
# 9      3510  ...  POLYGON ((-47.71366 -22.30191, -47.71455 -22.3...
# 10     3511  ...  MULTIPOLYGON (((-45.66298 -24.08365, -45.66318...
#
# [11 rows x 4 columns]

# %%
#Mapas das regiões intermediárias de SP
intermediarias = intermediarias.plot(figsize=(20,20), color = 'grey', edgecolor = 'white', linewidth = 1)
intermediarias.axis('off')
# Out:
# (-53.5575488504, -43.71392784560001, -25.63691697715, -19.50073859585)
